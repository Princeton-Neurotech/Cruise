# %%
# %matplotlib inline  

import mne
import numpy as np

raw = mne.io.read_raw_edf('person1alphatest.edf')
# Out:
# Extracting EDF parameters from /Users/thomasdhome/Desktop/CS PROJECTS/Brain-Gym/person1alphatest.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
raw.plot(scalings = 'auto');
# Out:
# <MNEBrowseFigure size 432x288 with 4 Axes>
